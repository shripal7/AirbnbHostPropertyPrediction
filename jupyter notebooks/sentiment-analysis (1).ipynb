# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cross_validation import train_test_split
from sklearn.naive_bayes import MultinomialNB
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA

# %%
# read data from csv into dataframes
airbnb = pd.read_csv('reviews_detail.csv')

# %%
airbnb.shape
Output: (10000, 10)

# %%
airbnb.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     9452127  58944174  2016-01-05      6279455          Ravi
# 1     9452127  59446510  2016-01-10     23770684          Shiv
# 2     9452127  59557387  2016-01-11     29070567       Jandall
# 3     9452127  62664325  2016-02-15     58381183          Cody
# 4     9452127  63410004  2016-02-22     29014080        Magnus
#
#                                             comments
# 0  Great place. Helena was prompt to reply and ve...
# 1  We had previously stayed at the apartment over...
# 2  Helena was a great host and extremely accommod...
# 3  Helena was extremely accessible throughout the...
# 4  Awesome place! Looks just as in photos. Plenty...

# %%
airbnb.describe()
# Out:
#          listing_id            id   reviewer_id
# count  8.017840e+05  8.017840e+05  8.017840e+05
# mean   7.181406e+06  9.945965e+07  4.231955e+07
# std    5.965983e+06  5.836603e+07  3.904014e+07
# min    2.515000e+03  1.980000e+02  1.000000e+00
# 25%    1.584167e+06  4.959375e+07  9.999482e+06
# 50%    5.918025e+06  1.027662e+08  2.967891e+07
# 75%    1.223196e+07  1.503660e+08  6.469194e+07
# max    2.115454e+07  1.997150e+08  1.526968e+08

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801784 entries, 0 to 801783
# Data columns (total 6 columns):
# listing_id       801784 non-null int64
# id               801784 non-null int64
# date             801784 non-null object
# reviewer_id      801784 non-null int64
# reviewer_name    801784 non-null object
# comments         801007 non-null object
# dtypes: int64(3), object(3)
# memory usage: 36.7+ MB

# %%
airbnb.comments.dtype
# Out:
# dtype('O')

# %%
# converting the comments/reviews data into string for later evaluation
airbnb['comments'] = airbnb['comments'].astype(str)

# %%
airbnb['text length'] = airbnb['comments'].apply(len)
airbnb.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     9452127  58944174  2016-01-05      6279455          Ravi
# 1     9452127  59446510  2016-01-10     23770684          Shiv
# 2     9452127  59557387  2016-01-11     29070567       Jandall
# 3     9452127  62664325  2016-02-15     58381183          Cody
# 4     9452127  63410004  2016-02-22     29014080        Magnus
#
#                                             comments  text length
# 0  Great place. Helena was prompt to reply and ve...          172
# 1  We had previously stayed at the apartment over...          456
# 2  Helena was a great host and extremely accommod...          210
# 3  Helena was extremely accessible throughout the...          426
# 4  Awesome place! Looks just as in photos. Plenty...          205

# %%
x = airbnb
# bow_transformer = CountVectorizer(analyzer=text_process).fit(X)

sid = SIA()
def posit(x):
    p = sid.polarity_scores(x)
    return p['pos']

def negit(x):
    p = sid.polarity_scores(x)
    return p['neg']

def neuit(x):
    p = sid.polarity_scores(x)
    return p['neu']


x['pos'] = x['comments'].apply(posit)
x['neg'] = x['comments'].apply(negit)
x['neu'] = x['comments'].apply(neuit)


#     if (abs(p['pos'] - p['neg']) <= 0.05):
#         a = 'neutral'
#     elif (p['pos'] - p['neg'] > 0.05):
#         a = 'positive'
#     else:
#         a ='negative'
#     print (a)
#     airbnb['type'] = append[a]

x.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     9452127  58944174  2016-01-05      6279455          Ravi
# 1     9452127  59446510  2016-01-10     23770684          Shiv
# 2     9452127  59557387  2016-01-11     29070567       Jandall
# 3     9452127  62664325  2016-02-15     58381183          Cody
# 4     9452127  63410004  2016-02-22     29014080        Magnus
#
#                                             comments  text length    pos  \
# 0  Great place. Helena was prompt to reply and ve...          172  0.308
# 1  We had previously stayed at the apartment over...          456  0.170
# 2  Helena was a great host and extremely accommod...          210  0.312
# 3  Helena was extremely accessible throughout the...          426  0.113
# 4  Awesome place! Looks just as in photos. Plenty...          205  0.349
#
#     neg    neu
# 0  0.00  0.692
# 1  0.06  0.770
# 2  0.00  0.688
# 3  0.00  0.887
# 4  0.00  0.651

# %%
# Aggregating total positives of listing ids
df = x.groupby('listing_id', sort=False)["pos"].sum().reset_index(name="Total positive")
df.head()
# Out:
#    listing_id  Total positive
# 0     9452127           7.279
# 1     6184827           1.150
# 2     6921831           2.114
# 3      766542           1.193
# 4     6078066          17.814

# %%
x.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     9452127  58944174  2016-01-05      6279455          Ravi
# 1     9452127  59446510  2016-01-10     23770684          Shiv
# 2     9452127  59557387  2016-01-11     29070567       Jandall
# 3     9452127  62664325  2016-02-15     58381183          Cody
# 4     9452127  63410004  2016-02-22     29014080        Magnus
#
#                                             comments  text length    pos  \
# 0  Great place. Helena was prompt to reply and ve...          172  0.308
# 1  We had previously stayed at the apartment over...          456  0.170
# 2  Helena was a great host and extremely accommod...          210  0.312
# 3  Helena was extremely accessible throughout the...          426  0.113
# 4  Awesome place! Looks just as in photos. Plenty...          205  0.349
#
#     neg    neu
# 0  0.00  0.692
# 1  0.06  0.770
# 2  0.00  0.688
# 3  0.00  0.887
# 4  0.00  0.651

# %%
#  Copying the required fields into new data frame
keeper = x[['pos', 'neg', 'neu']].copy()
keeper.head()
# Out:
#      pos   neg    neu
# 0  0.308  0.00  0.692
# 1  0.170  0.06  0.770
# 2  0.312  0.00  0.688
# 3  0.113  0.00  0.887
# 4  0.349  0.00  0.651

# %%
# Writing the sentiment analysis file into a csv file
keeper.to_csv("sentiments_store.csv", sep='\t', encoding='utf-8')
